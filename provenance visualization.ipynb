# %% [markdown]
# # Visualizing Provenance from a Semantic Container
#
# In this demo we will look at the provenance information from a semantic container. The provenance information can be access along with the data and usage policy in `/api/data/provision`.

# %%
prov_url = "https://vownyourdata.zamg.ac.at:9505/api/data/provision"

# %%
import requests

# %%
r = requests.get(prov_url)

# %% [markdown]
# The request will return a JSON document, where the provenance information is available in the `$.provenance` path of the document.

# %%
provision = r.json()['provenance']

# %% [markdown]
# The provenance is described using RDF format using PROV-O Ontology. Therefore we will need to use `rdflib` library to access it.

# %%
from rdflib import ConjunctiveGraph as Graph

# %%
g = Graph()
g.parse(data=provision, format="trig")
len(g)
# Out:
# 951

# %% [markdown]
# Now let's have a look at the provenance information. We can just use TURTLE serialization format for human-readable RDF document.

# %%
print(g.serialize(format="turtle").decode("utf-8"))
# Out:
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sc: <http://w3id.org/semcon/ns/ontology#> .
# @prefix scr: <http://w3id.org/semcon/resource/> .
# @prefix void: <http://rdfs.org/ns/void#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# scr:input_0077304d8b68 a prov:Activity ;
#     rdfs:label "input data from 2019-04-19T00:00:12Z"^^xsd:string ;
#     sc:inputHash "0077304d8b686e2db6bb96cdcbe7b5c5245966607f3054b4b7daa5cbe7700ee8"^^xsd:string ;
#     prov:endedAtTime "2019-04-19T00:00:12+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-19T00:00:12+00:00"^^xsd:dateTime ;
#     prov:used scr:data_bfa14dbae93c_e1219b99 .
#
# scr:input_03e046eb244f_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-08T00:00:01Z"^^xsd:string ;
#     sc:inputHash "03e046eb244f2f228f95e77d1bf75022e184dd755ff0305d22340e992c2668ee"^^xsd:string ;
#     prov:endedAtTime "2019-04-08T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_03e046eb244f_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-08T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_03e8cef1559d_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-03T00:00:01Z"^^xsd:string ;
#     sc:inputHash "03e8cef1559d6a7f39ab3951884be444217be7c4e396225494d41c1fdb3880d2"^^xsd:string ;
#     prov:endedAtTime "2019-04-03T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_03e8cef1559d_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-03T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_06052e4f9c98_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-24T00:00:04Z"^^xsd:string ;
#     sc:inputHash "06052e4f9c98040b342dfd50045086f6d0c10151c282d23499e5c991ed5bee3b"^^xsd:string ;
#     prov:endedAtTime "2019-04-24T00:00:04+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_06052e4f9c98_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-24T00:00:03+00:00"^^xsd:dateTime .
#
# scr:input_118b5885e7e0 a prov:Activity ;
#     rdfs:label "input data from 2019-04-16T00:00:56Z"^^xsd:string ;
#     sc:inputHash "118b5885e7e0d62d487f541471b2718463f916ce8ed23636dca078c769285ca4"^^xsd:string ;
#     prov:endedAtTime "2019-04-16T00:00:56+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-16T00:00:54+00:00"^^xsd:dateTime ;
#     prov:used scr:data_1343e217b0fc_e1219b99 .
#
# scr:input_1343e217b0fc_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-16T00:00:21Z"^^xsd:string ;
#     sc:inputHash "1343e217b0fc6794c3787924f49cea83b6c2cc3b47fb827ed2945057c144a4e0"^^xsd:string ;
#     prov:endedAtTime "2019-04-16T00:00:21+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_1343e217b0fc_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-16T00:00:18+00:00"^^xsd:dateTime .
#
# scr:input_16262fedeaf9_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-28T00:00:08Z"^^xsd:string ;
#     sc:inputHash "16262fedeaf92dcc2b9d7ef23fe91d3a1f2c45efb57e2c66381fd5f8fc9fd7e7"^^xsd:string ;
#     prov:endedAtTime "2019-04-28T00:00:08+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_16262fedeaf9_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-28T00:00:07+00:00"^^xsd:dateTime .
#
# scr:input_1794cf929fc3 a prov:Activity ;
#     rdfs:label "input data from 2019-03-28T00:00:06Z"^^xsd:string ;
#     sc:inputHash "1794cf929fc318e676eda2ffd8b108a5e45736a6574926ae825ac3c8f9c49fdc"^^xsd:string ;
#     prov:endedAtTime "2019-03-28T00:00:06+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-03-28T00:00:05+00:00"^^xsd:dateTime ;
#     prov:used scr:data_beea0b9c9401_e1219b99 .
#
# scr:input_1a7c80cb5164_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-10T00:00:01Z"^^xsd:string ;
#     sc:inputHash "1a7c80cb51640678d76cf98f2f2cae7a72035090dd758bf27eaee225713b5199"^^xsd:string ;
#     prov:endedAtTime "2019-04-10T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_1a7c80cb5164_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-10T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_1ab8d7b291f3 a prov:Activity ;
#     rdfs:label "input data from 2019-04-18T00:00:21Z"^^xsd:string ;
#     sc:inputHash "1ab8d7b291f3df8951fc0280445ff583ce0950978085637cf230e842a212be0b"^^xsd:string ;
#     prov:endedAtTime "2019-04-18T00:00:21+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-18T00:00:21+00:00"^^xsd:dateTime ;
#     prov:used scr:data_a9cd50b1a8d3_e1219b99 .
#
# scr:input_1ce9f5def6ba a prov:Activity ;
#     rdfs:label "input data from 2019-04-07T00:00:06Z"^^xsd:string ;
#     sc:inputHash "1ce9f5def6bad2e1391345e736c304b967a4a5c9f3fb981a2af80b806c551ef7"^^xsd:string ;
#     prov:endedAtTime "2019-04-07T00:00:06+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-07T00:00:06+00:00"^^xsd:dateTime ;
#     prov:used scr:data_4e9c9a956594_e1219b99 .
#
# scr:input_1e1b22c9614d_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-05T00:00:01Z"^^xsd:string ;
#     sc:inputHash "1e1b22c9614da726e0c8a417c5a4691beb8db9eda2c110c9dad5dd30d5e5e80d"^^xsd:string ;
#     prov:endedAtTime "2019-04-05T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_1e1b22c9614d_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-05T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_20ea4178e81d a prov:Activity ;
#     rdfs:label "input data from 2019-03-24T00:00:04Z"^^xsd:string ;
#     sc:inputHash "20ea4178e81d9a5809fd37d2c43d5e751b110eb1c66668fa5eeab8bcd7739b89"^^xsd:string ;
#     prov:endedAtTime "2019-03-24T00:00:04+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-03-24T00:00:04+00:00"^^xsd:dateTime ;
#     prov:used scr:data_884c046c9736_e1219b99 .
#
# scr:input_2194589a66f9 a prov:Activity ;
#     rdfs:label "input data from 2019-04-11T00:00:04Z"^^xsd:string ;
#     sc:inputHash "2194589a66f98e0cf824a34d010c3e8e2fce913e68f0fa78aa8497c4a5c00907"^^xsd:string ;
#     prov:endedAtTime "2019-04-11T00:00:04+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-11T00:00:04+00:00"^^xsd:dateTime ;
#     prov:used scr:data_2b2dfcb5ecd1_e1219b99 .
#
# scr:input_219ac0241153_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-30T00:00:12Z"^^xsd:string ;
#     sc:inputHash "219ac02411531a3aaee88fa76948a464f939fc12b8e6ec0ead3fa5a7bd45318c"^^xsd:string ;
#     prov:endedAtTime "2019-04-30T00:00:12+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_219ac0241153_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-30T00:00:10+00:00"^^xsd:dateTime .
#
# scr:input_2249aeb4cb7c a prov:Activity ;
#     rdfs:label "input data from 2019-04-28T00:00:29Z"^^xsd:string ;
#     sc:inputHash "2249aeb4cb7cc9bbb33ca7b4a31583f15aead61322144479e51ca2d9e7a8058a"^^xsd:string ;
#     prov:endedAtTime "2019-04-28T00:00:29+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-28T00:00:27+00:00"^^xsd:dateTime ;
#     prov:used scr:data_16262fedeaf9_e1219b99 .
#
# scr:input_26754122f832_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-03-30T00:00:02Z"^^xsd:string ;
#     sc:inputHash "26754122f8320b012045c4c0964bed03d654db747228c3d0d9353e5ea3e51e22"^^xsd:string ;
#     prov:endedAtTime "2019-03-30T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_26754122f832_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-03-30T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_26c6e712b32c_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-27T00:00:03Z"^^xsd:string ;
#     sc:inputHash "26c6e712b32cf230868481d305c3b45ce25d89e51516a508e447546a78587544"^^xsd:string ;
#     prov:endedAtTime "2019-04-27T00:00:03+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_26c6e712b32c_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-27T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_274599f4a814 a prov:Activity ;
#     rdfs:label "input data from 2019-05-02T00:00:25Z"^^xsd:string ;
#     sc:inputHash "274599f4a8148490ba08f2da89ca4bb2de8f210817863d47bdb7d82edd06a7a7"^^xsd:string ;
#     prov:endedAtTime "2019-05-02T00:00:25+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-05-02T00:00:23+00:00"^^xsd:dateTime ;
#     prov:used scr:data_b383e84cd3bf_e1219b99 .
#
# scr:input_27ab5532fa53 a prov:Activity ;
#     rdfs:label "input data from 2019-03-25T00:00:04Z"^^xsd:string ;
#     sc:inputHash "27ab5532fa538816755f119a22b0e1cfde39e078040010796196cd387f92112e"^^xsd:string ;
#     prov:endedAtTime "2019-03-25T00:00:04+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-03-25T00:00:04+00:00"^^xsd:dateTime ;
#     prov:used scr:data_f8cd84c323dd_e1219b99 .
#
# scr:input_2b2dfcb5ecd1_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-11T00:00:02Z"^^xsd:string ;
#     sc:inputHash "2b2dfcb5ecd1b28cb78e0718e34e065396ff6a9ebca3a06f5fc55cf0d6a22505"^^xsd:string ;
#     prov:endedAtTime "2019-04-11T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_2b2dfcb5ecd1_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-11T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_38267ed282a6 a prov:Activity ;
#     rdfs:label "input data from 2019-04-08T00:00:09Z"^^xsd:string ;
#     sc:inputHash "38267ed282a669dd7be577f79504f1a4b04deb890056f6573bb7998e1e114614"^^xsd:string ;
#     prov:endedAtTime "2019-04-08T00:00:09+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-08T00:00:09+00:00"^^xsd:dateTime ;
#     prov:used scr:data_03e046eb244f_e1219b99 .
#
# scr:input_3d425177d35a a prov:Activity ;
#     rdfs:label "input data from 2019-03-31T00:00:05Z"^^xsd:string ;
#     sc:inputHash "3d425177d35aff25ab32d79b8af46adccbaf343ee96c220aa92b322068fd2e0d"^^xsd:string ;
#     prov:endedAtTime "2019-03-31T00:00:05+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-03-31T00:00:05+00:00"^^xsd:dateTime ;
#     prov:used scr:data_49dda3a5b415_e1219b99 .
#
# scr:input_420eff6352e2 a prov:Activity ;
#     rdfs:label "input data from 2019-04-30T00:00:39Z"^^xsd:string ;
#     sc:inputHash "420eff6352e2c8f322af63ba4109c634f3f179719f59f19b310c30d958389da0"^^xsd:string ;
#     prov:endedAtTime "2019-04-30T00:00:39+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-30T00:00:37+00:00"^^xsd:dateTime ;
#     prov:used scr:data_219ac0241153_e1219b99 .
#
# scr:input_49dda3a5b415_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-03-31T00:00:02Z"^^xsd:string ;
#     sc:inputHash "49dda3a5b4159ccd91d87390efdb05a787d821fd0b831d4fdd3ba284b8a4e009"^^xsd:string ;
#     prov:endedAtTime "2019-03-31T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_49dda3a5b415_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-03-31T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_4e9c9a956594_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-07T00:00:02Z"^^xsd:string ;
#     sc:inputHash "4e9c9a956594812e3d1f29c699bda1d11476dbe8c29f52024c52d612260bc222"^^xsd:string ;
#     prov:endedAtTime "2019-04-07T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_4e9c9a956594_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-07T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_4ecd7ee2fb70 a prov:Activity ;
#     rdfs:label "input data from 2019-03-27T00:00:08Z"^^xsd:string ;
#     sc:inputHash "4ecd7ee2fb709c2b0994a51220593fa42db4a88eb6da19a220da4f72cdccf848"^^xsd:string ;
#     prov:endedAtTime "2019-03-27T00:00:08+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-03-27T00:00:08+00:00"^^xsd:dateTime ;
#     prov:used scr:data_98e849808579_e1219b99 .
#
# scr:input_4f74eb37f31d_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-03-23T00:00:01Z"^^xsd:string ;
#     sc:inputHash "4f74eb37f31d8fbe3ff8ddcba9756daa06a76edf8abc121c892492043743155c"^^xsd:string ;
#     prov:endedAtTime "2019-03-23T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_4f74eb37f31d_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-03-23T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_519d6ff9df57_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-26T00:00:04Z"^^xsd:string ;
#     sc:inputHash "519d6ff9df57ccde09b322dd1386f982713e8d54791ac2b3c40984c6a227bca5"^^xsd:string ;
#     prov:endedAtTime "2019-04-26T00:00:04+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_519d6ff9df57_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-26T00:00:03+00:00"^^xsd:dateTime .
#
# scr:input_532a19ffd2ea a prov:Activity ;
#     rdfs:label "input data from 2019-04-06T00:00:06Z"^^xsd:string ;
#     sc:inputHash "532a19ffd2ea5b30547e8c48d5e7adc135b79ee8033af557fb8278d20795d219"^^xsd:string ;
#     prov:endedAtTime "2019-04-06T00:00:06+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-06T00:00:06+00:00"^^xsd:dateTime ;
#     prov:used scr:data_e549c920185d_e1219b99 .
#
# scr:input_5bee1e4893e1 a prov:Activity ;
#     rdfs:label "input data from 2019-04-26T00:00:07Z"^^xsd:string ;
#     sc:inputHash "5bee1e4893e1e687090d96a5242a143a9bf17fde35e60ef7487bcee43105c38a"^^xsd:string ;
#     prov:endedAtTime "2019-04-26T00:00:07+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-26T00:00:07+00:00"^^xsd:dateTime ;
#     prov:used scr:data_519d6ff9df57_e1219b99 .
#
# scr:input_5dd32203717e a prov:Activity ;
#     rdfs:label "input data from 2019-03-26T00:00:04Z"^^xsd:string ;
#     sc:inputHash "5dd32203717ed1a2bd56643e8b52dbee92ec03303a33472ff1c8f7f905644688"^^xsd:string ;
#     prov:endedAtTime "2019-03-26T00:00:04+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-03-26T00:00:04+00:00"^^xsd:dateTime ;
#     prov:used scr:data_7d2695093848_e1219b99 .
#
# scr:input_5ee1b22d3b50 a prov:Activity ;
#     rdfs:label "input data from 2019-04-21T00:00:07Z"^^xsd:string ;
#     sc:inputHash "5ee1b22d3b509a65018db0164277d1339d521fadc7aa79c5a0870196d5c4cfc1"^^xsd:string ;
#     prov:endedAtTime "2019-04-21T00:00:07+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-21T00:00:07+00:00"^^xsd:dateTime ;
#     prov:used scr:data_8b7408f76a55_e1219b99 .
#
# scr:input_622fb833fd5c_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-13T00:00:28Z"^^xsd:string ;
#     sc:inputHash "622fb833fd5cbc122a2542ff4c7d8746bcf13da2f35d0e552d01f1bc8a7094aa"^^xsd:string ;
#     prov:endedAtTime "2019-04-13T00:00:28+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_622fb833fd5c_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-13T00:00:25+00:00"^^xsd:dateTime .
#
# scr:input_62c1f359fa8b_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-03-21T21:48:13Z"^^xsd:string ;
#     sc:inputHash "62c1f359fa8b77a4950db7210307ad89c5f2fbbb839d854fe6a2b532c648d797"^^xsd:string ;
#     prov:endedAtTime "2019-03-21T21:48:13+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_62c1f359fa8b_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment ""^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-03-21T21:48:13+00:00"^^xsd:dateTime .
#
# scr:input_658bf7f78933_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-03-29T00:00:01Z"^^xsd:string ;
#     sc:inputHash "658bf7f78933e16835e7fd17a34f12dc83e90eb16707dc25035f769c2375c5df"^^xsd:string ;
#     prov:endedAtTime "2019-03-29T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_658bf7f78933_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-03-29T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_6dff31e6467f a prov:Activity ;
#     rdfs:label "input data from 2019-04-29T00:00:22Z"^^xsd:string ;
#     sc:inputHash "6dff31e6467f8cd864e1937234ed4391a90ae4e117c202c8b44b396738626b6b"^^xsd:string ;
#     prov:endedAtTime "2019-04-29T00:00:22+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-29T00:00:21+00:00"^^xsd:dateTime ;
#     prov:used scr:data_e181e86cff83_e1219b99 .
#
# scr:input_79ff59ae1aad a prov:Activity ;
#     rdfs:label "input data from 2019-03-23T00:00:05Z"^^xsd:string ;
#     sc:inputHash "79ff59ae1aadeafbe634e2123ecae9a76aadc6c377a264e8a1a6975c3d5ffddf"^^xsd:string ;
#     prov:endedAtTime "2019-03-23T00:00:05+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-03-23T00:00:04+00:00"^^xsd:dateTime ;
#     prov:used scr:data_4f74eb37f31d_e1219b99 .
#
# scr:input_7d2695093848_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-03-26T00:00:01Z"^^xsd:string ;
#     sc:inputHash "7d269509384829bfea1806f5c3ca137b68dbd52a40f6758835699b95f275d0d6"^^xsd:string ;
#     prov:endedAtTime "2019-03-26T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_7d2695093848_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-03-26T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_85e19257c71a a prov:Activity ;
#     rdfs:label "input data from 2019-03-29T00:00:13Z"^^xsd:string ;
#     sc:inputHash "85e19257c71a270f56534f5f059a5dca57bf72db78d66204d4c95866ad5c0ef4"^^xsd:string ;
#     prov:endedAtTime "2019-03-29T00:00:13+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-03-29T00:00:12+00:00"^^xsd:dateTime ;
#     prov:used scr:data_658bf7f78933_e1219b99 .
#
# scr:input_87c851f534de_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-14T00:00:05Z"^^xsd:string ;
#     sc:inputHash "87c851f534debee76dfbe5c5515c2aef4f5f166264667dc85d54bdf700c47afe"^^xsd:string ;
#     prov:endedAtTime "2019-04-14T00:00:05+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_87c851f534de_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-14T00:00:04+00:00"^^xsd:dateTime .
#
# scr:input_87f951443621_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-01T00:00:01Z"^^xsd:string ;
#     sc:inputHash "87f951443621c009d4375e1e025cb709942ae298bc0198208afc339a6992dab6"^^xsd:string ;
#     prov:endedAtTime "2019-04-01T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_87f951443621_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-01T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_884c046c9736_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-03-24T00:00:01Z"^^xsd:string ;
#     sc:inputHash "884c046c9736ee697927ce4c30af1b28bdf9c01c93af72be5bcccf3c330c4c94"^^xsd:string ;
#     prov:endedAtTime "2019-03-24T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_884c046c9736_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-03-24T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_8b7408f76a55_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-21T00:00:02Z"^^xsd:string ;
#     sc:inputHash "8b7408f76a55de65098daad535e6a799db9479ed19d15b87005a6f201071df50"^^xsd:string ;
#     prov:endedAtTime "2019-04-21T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_8b7408f76a55_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-21T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_9373b4cd3366 a prov:Activity ;
#     rdfs:label "input data from 2019-04-01T00:00:07Z"^^xsd:string ;
#     sc:inputHash "9373b4cd336671728a6c9d5f8d51d87ebf7f60a981a79939b89da6eb1dae1c07"^^xsd:string ;
#     prov:endedAtTime "2019-04-01T00:00:07+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-01T00:00:07+00:00"^^xsd:dateTime ;
#     prov:used scr:data_87f951443621_e1219b99 .
#
# scr:input_969c3da91075 a prov:Activity ;
#     rdfs:label "input data from 2019-04-24T00:00:07Z"^^xsd:string ;
#     sc:inputHash "969c3da91075cb1b43bdb47d0312d9e09893081012c83c4136c499b9f99ce67a"^^xsd:string ;
#     prov:endedAtTime "2019-04-24T00:00:07+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-24T00:00:07+00:00"^^xsd:dateTime ;
#     prov:used scr:data_06052e4f9c98_e1219b99 .
#
# scr:input_9878053b168f_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-12T00:00:02Z"^^xsd:string ;
#     sc:inputHash "9878053b168f3807f6887f18ef8bdac499a9c2d1c0909e4463aa34d119f97988"^^xsd:string ;
#     prov:endedAtTime "2019-04-12T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_9878053b168f_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-12T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_9880b63a8562_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-09T00:00:02Z"^^xsd:string ;
#     sc:inputHash "9880b63a8562cdaaf67943b72125760e47c1464411487d2fe7e187c2f7ed770e"^^xsd:string ;
#     prov:endedAtTime "2019-04-09T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_9880b63a8562_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-09T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_98e849808579_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-03-27T00:00:02Z"^^xsd:string ;
#     sc:inputHash "98e849808579cee969f97514c385c329c1407bdc1a74fadeb5b4edcfd2f5d8a8"^^xsd:string ;
#     prov:endedAtTime "2019-03-27T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_98e849808579_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-03-27T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_9a40f3024fab a prov:Activity ;
#     rdfs:label "input data from 2019-04-13T00:00:45Z"^^xsd:string ;
#     sc:inputHash "9a40f3024faba8033866bdf09f9eff942446646fc8bb25fce1b74626f3c9ef90"^^xsd:string ;
#     prov:endedAtTime "2019-04-13T00:00:45+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-13T00:00:43+00:00"^^xsd:dateTime ;
#     prov:used scr:data_622fb833fd5c_e1219b99 .
#
# scr:input_9b8d2b91aa3c_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-02T00:00:02Z"^^xsd:string ;
#     sc:inputHash "9b8d2b91aa3cd166fab783da509a3a9908ae598dbcacc0826af8f0018b5d911c"^^xsd:string ;
#     prov:endedAtTime "2019-04-02T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_9b8d2b91aa3c_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-02T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_9dc2d7d1b729 a prov:Activity ;
#     rdfs:label "input data from 2019-03-30T00:00:07Z"^^xsd:string ;
#     sc:inputHash "9dc2d7d1b72952f79ca4e4413b784b27567a089f7575b762ed09ebb5021e61fd"^^xsd:string ;
#     prov:endedAtTime "2019-03-30T00:00:07+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-03-30T00:00:07+00:00"^^xsd:dateTime ;
#     prov:used scr:data_26754122f832_e1219b99 .
#
# scr:input_9ffb5b3d5a50 a prov:Activity ;
#     rdfs:label "input data from 2019-04-15T00:00:18Z"^^xsd:string ;
#     sc:inputHash "9ffb5b3d5a50dd346e246182c1f2d18a76b2270595e79486bbfbb9a67a236e14"^^xsd:string ;
#     prov:endedAtTime "2019-04-15T00:00:18+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-15T00:00:18+00:00"^^xsd:dateTime ;
#     prov:used scr:data_dfc3c2cd4e32_e1219b99 .
#
# scr:input_a419148e2936_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-20T00:00:02Z"^^xsd:string ;
#     sc:inputHash "a419148e29366036e32969521d2ab36146f7ec28f15ffba6b5dda79f9e6d3186"^^xsd:string ;
#     prov:endedAtTime "2019-04-20T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_a419148e2936_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-20T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_a565a05a41e5_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-17T00:00:15Z"^^xsd:string ;
#     sc:inputHash "a565a05a41e592115696d84e57607595d21500365dc93d50d853cb4a0c685a38"^^xsd:string ;
#     prov:endedAtTime "2019-04-17T00:00:15+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_a565a05a41e5_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-17T00:00:12+00:00"^^xsd:dateTime .
#
# scr:input_a6a58014d270_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-05-01T00:00:03Z"^^xsd:string ;
#     sc:inputHash "a6a58014d270ad1c23a99a15f337110f109a927c7c0b12144e04f4f113423c6e"^^xsd:string ;
#     prov:endedAtTime "2019-05-01T00:00:03+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_a6a58014d270_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-05-01T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_a757587ad2df a prov:Activity ;
#     rdfs:label "input data from 2019-04-27T00:00:16Z"^^xsd:string ;
#     sc:inputHash "a757587ad2df9e62cf2005446c23e3ae597ec75672f1e5415cb0e35d7f7d85da"^^xsd:string ;
#     prov:endedAtTime "2019-04-27T00:00:16+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-27T00:00:15+00:00"^^xsd:dateTime ;
#     prov:used scr:data_26c6e712b32c_e1219b99 .
#
# scr:input_a9638234d5d8 a prov:Activity ;
#     rdfs:label "input data from 2019-04-12T00:00:08Z"^^xsd:string ;
#     sc:inputHash "a9638234d5d878fb23c4aa28b8fcc036b0d15ded574e82bfd5be368e4f25a63f"^^xsd:string ;
#     prov:endedAtTime "2019-04-12T00:00:08+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-12T00:00:07+00:00"^^xsd:dateTime ;
#     prov:used scr:data_9878053b168f_e1219b99 .
#
# scr:input_a9cd50b1a8d3_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-18T00:00:07Z"^^xsd:string ;
#     sc:inputHash "a9cd50b1a8d3747f7cd2c9a0babe087bffa51f39b9811cad4655beb167bfe1da"^^xsd:string ;
#     prov:endedAtTime "2019-04-18T00:00:07+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_a9cd50b1a8d3_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-18T00:00:06+00:00"^^xsd:dateTime .
#
# scr:input_ad71a5648142 a prov:Activity ;
#     rdfs:label "input data from 2019-04-05T00:00:03Z"^^xsd:string ;
#     sc:inputHash "ad71a56481422575f8dee91805e212693226639db3f2a3e79432a8df8817e316"^^xsd:string ;
#     prov:endedAtTime "2019-04-05T00:00:03+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-05T00:00:03+00:00"^^xsd:dateTime ;
#     prov:used scr:data_1e1b22c9614d_e1219b99 .
#
# scr:input_b383e84cd3bf_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-05-02T00:00:07Z"^^xsd:string ;
#     sc:inputHash "b383e84cd3bfc523b922634ff8a390e6178501fd32ed0a1af19148f6402b85da"^^xsd:string ;
#     prov:endedAtTime "2019-05-02T00:00:07+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_b383e84cd3bf_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-05-02T00:00:06+00:00"^^xsd:dateTime .
#
# scr:input_b47266abf839 a prov:Activity ;
#     rdfs:label "input data from 2019-04-25T00:00:05Z"^^xsd:string ;
#     sc:inputHash "b47266abf8390f7e780dc89cc6d4edde07df6516aaec1eb18e4137cb5aefca8f"^^xsd:string ;
#     prov:endedAtTime "2019-04-25T00:00:05+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-25T00:00:05+00:00"^^xsd:dateTime ;
#     prov:used scr:data_d7a7b1da1156_e1219b99 .
#
# scr:input_b4e6f971b245_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-04T00:00:01Z"^^xsd:string ;
#     sc:inputHash "b4e6f971b2455fc2fc75014120ac231161abf7aaf81d742b6b25aaf1b0fc7262"^^xsd:string ;
#     prov:endedAtTime "2019-04-04T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_b4e6f971b245_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-04T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_b86d56c18948_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-22T00:00:01Z"^^xsd:string ;
#     sc:inputHash "b86d56c18948e7e098b93accb962f0c3fcfba56bc0b899cea941290d6aa997fb"^^xsd:string ;
#     prov:endedAtTime "2019-04-22T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_b86d56c18948_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-22T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_beea0b9c9401_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-03-28T00:00:01Z"^^xsd:string ;
#     sc:inputHash "beea0b9c940178f3ef6a33a38f8ebfc6bbf0636f0036e5492e6e13e919f29f72"^^xsd:string ;
#     prov:endedAtTime "2019-03-28T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_beea0b9c9401_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-03-28T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_bf7ba0c4109c a prov:Activity ;
#     rdfs:label "input data from 2019-04-03T00:00:07Z"^^xsd:string ;
#     sc:inputHash "bf7ba0c4109c7ad8ab8e195f9571d262139ba026b3dd83d0965e78ca50ae509c"^^xsd:string ;
#     prov:endedAtTime "2019-04-03T00:00:07+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-03T00:00:07+00:00"^^xsd:dateTime ;
#     prov:used scr:data_03e8cef1559d_e1219b99 .
#
# scr:input_bfa14dbae93c_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-19T00:00:04Z"^^xsd:string ;
#     sc:inputHash "bfa14dbae93c44b9d7f89118131732073eb7a3d2fdb3dd40d314df3678404658"^^xsd:string ;
#     prov:endedAtTime "2019-04-19T00:00:04+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_bfa14dbae93c_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-19T00:00:03+00:00"^^xsd:dateTime .
#
# scr:input_c37cff60885b a prov:Activity ;
#     rdfs:label "input data from 2019-05-01T00:00:15Z"^^xsd:string ;
#     sc:inputHash "c37cff60885b6512ac6786baafd4a0ddbe31d68c40bf927196e2d075cca16abf"^^xsd:string ;
#     prov:endedAtTime "2019-05-01T00:00:15+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-05-01T00:00:14+00:00"^^xsd:dateTime ;
#     prov:used scr:data_a6a58014d270_e1219b99 .
#
# scr:input_c3a24c82f13e a prov:Activity ;
#     rdfs:label "input data from 2019-04-02T00:00:07Z"^^xsd:string ;
#     sc:inputHash "c3a24c82f13e2c243e7e844aa6c7caa9316d3409dd7f6d7891b4abacc2d16d68"^^xsd:string ;
#     prov:endedAtTime "2019-04-02T00:00:07+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-02T00:00:06+00:00"^^xsd:dateTime ;
#     prov:used scr:data_9b8d2b91aa3c_e1219b99 .
#
# scr:input_c793d358294e a prov:Activity ;
#     rdfs:label "input data from 2019-04-22T00:00:07Z"^^xsd:string ;
#     sc:inputHash "c793d358294e87d24e720658923c85b3b55aa18f8bac89d4f8971e8cd0be92a5"^^xsd:string ;
#     prov:endedAtTime "2019-04-22T00:00:07+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-22T00:00:07+00:00"^^xsd:dateTime ;
#     prov:used scr:data_b86d56c18948_e1219b99 .
#
# scr:input_cfcf7de7a3a6 a prov:Activity ;
#     rdfs:label "input data from 2019-04-23T00:00:06Z"^^xsd:string ;
#     sc:inputHash "cfcf7de7a3a6bf5525bfe3a015a6b2e843476bf37603f2c8d2865b1848fb257c"^^xsd:string ;
#     prov:endedAtTime "2019-04-23T00:00:06+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-23T00:00:06+00:00"^^xsd:dateTime ;
#     prov:used scr:data_f38589020f25_e1219b99 .
#
# scr:input_d7a7b1da1156_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-25T00:00:02Z"^^xsd:string ;
#     sc:inputHash "d7a7b1da11560c9352ca6fe85744cd3f46946911baaf6013d463448221e2461c"^^xsd:string ;
#     prov:endedAtTime "2019-04-25T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_d7a7b1da1156_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-25T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_dfc3c2cd4e32_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-15T00:00:14Z"^^xsd:string ;
#     sc:inputHash "dfc3c2cd4e3283aa6fdc73c6868e349aaf5d6aa86429f41be26062f6e2b37b85"^^xsd:string ;
#     prov:endedAtTime "2019-04-15T00:00:14+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_dfc3c2cd4e32_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-15T00:00:08+00:00"^^xsd:dateTime .
#
# scr:input_e181e86cff83_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-29T00:00:04Z"^^xsd:string ;
#     sc:inputHash "e181e86cff838dc43c8a6ddb7674b885fb4bb24d7a92736fdc914276fb6bde33"^^xsd:string ;
#     prov:endedAtTime "2019-04-29T00:00:04+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_e181e86cff83_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-29T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_e549c920185d_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-06T00:00:02Z"^^xsd:string ;
#     sc:inputHash "e549c920185dc1f8ea38288fc3e25f889596d20f315d4bdb6f2feec51407ae0a"^^xsd:string ;
#     prov:endedAtTime "2019-04-06T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_e549c920185d_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-06T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_e6c291d5eb39 a prov:Activity ;
#     rdfs:label "input data from 2019-03-21T21:48:20Z"^^xsd:string ;
#     sc:inputHash "e6c291d5eb39fc2d49fa5f2c2b9c50abd4783c48fd8a26128eeeeb5b5f4a0739"^^xsd:string ;
#     prov:endedAtTime "2019-03-21T21:48:20+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-03-21T21:48:16+00:00"^^xsd:dateTime ;
#     prov:used scr:data_62c1f359fa8b_e1219b99 .
#
# scr:input_ea136b04fb6c a prov:Activity ;
#     rdfs:label "input data from 2019-04-20T00:00:06Z"^^xsd:string ;
#     sc:inputHash "ea136b04fb6c24f3f49917cf95f815ceadb0c79e1ea1d3db969f9a7da8d43498"^^xsd:string ;
#     prov:endedAtTime "2019-04-20T00:00:06+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-20T00:00:06+00:00"^^xsd:dateTime ;
#     prov:used scr:data_a419148e2936_e1219b99 .
#
# scr:input_ed429f897505 a prov:Activity ;
#     rdfs:label "input data from 2019-04-17T00:00:42Z"^^xsd:string ;
#     sc:inputHash "ed429f897505d3d5e33dd50c7815a3eb48f79f7f7fceb805d4a815d3f3923c16"^^xsd:string ;
#     prov:endedAtTime "2019-04-17T00:00:42+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-17T00:00:39+00:00"^^xsd:dateTime ;
#     prov:used scr:data_a565a05a41e5_e1219b99 .
#
# scr:input_f1bf562d2a87 a prov:Activity ;
#     rdfs:label "input data from 2019-04-14T00:00:08Z"^^xsd:string ;
#     sc:inputHash "f1bf562d2a8787720887942b15b9b6651b0ce9fe48d1211629cded7b5bb0d558"^^xsd:string ;
#     prov:endedAtTime "2019-04-14T00:00:08+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-14T00:00:08+00:00"^^xsd:dateTime ;
#     prov:used scr:data_87c851f534de_e1219b99 .
#
# scr:input_f2640ff27bb6 a prov:Activity ;
#     rdfs:label "input data from 2019-04-04T00:00:05Z"^^xsd:string ;
#     sc:inputHash "f2640ff27bb6abcfb00120ce4d5dc57711b8fd0f2b4791b644de9b95df759636"^^xsd:string ;
#     prov:endedAtTime "2019-04-04T00:00:05+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-04T00:00:05+00:00"^^xsd:dateTime ;
#     prov:used scr:data_b4e6f971b245_e1219b99 .
#
# scr:input_f38589020f25_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-04-23T00:00:02Z"^^xsd:string ;
#     sc:inputHash "f38589020f256ecd8385ef96f19f2cbe7ee0502050f08c3686327d2b356af742"^^xsd:string ;
#     prov:endedAtTime "2019-04-23T00:00:02+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_f38589020f25_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-04-23T00:00:02+00:00"^^xsd:dateTime .
#
# scr:input_f81229314e59 a prov:Activity ;
#     rdfs:label "input data from 2019-04-10T00:00:09Z"^^xsd:string ;
#     sc:inputHash "f81229314e592b649c5351ec1d074ae65344d36665a813089aad0193d0c5b867"^^xsd:string ;
#     prov:endedAtTime "2019-04-10T00:00:09+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-10T00:00:09+00:00"^^xsd:dateTime ;
#     prov:used scr:data_1a7c80cb5164_e1219b99 .
#
# scr:input_f8cd84c323dd_e1219b99 a prov:Activity ;
#     rdfs:label "data input from 2019-03-25T00:00:01Z"^^xsd:string ;
#     sc:inputHash "f8cd84c323dd1560e34d97e6632a634f500da6fbf33f23bf239f91c3ff31eaa7"^^xsd:string ;
#     prov:endedAtTime "2019-03-25T00:00:01+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_f8cd84c323dd_e1219b99 ;
#     prov:qualifiedUsage [ a prov:Usage ;
#             rdfs:comment "duration=1"^^xsd:string ;
#             prov:entity scr:source_0daa8a2813e5 ] ;
#     prov:startedAtTime "2019-03-25T00:00:01+00:00"^^xsd:dateTime .
#
# scr:input_fe2917b599ad a prov:Activity ;
#     rdfs:label "input data from 2019-04-09T00:00:08Z"^^xsd:string ;
#     sc:inputHash "fe2917b599ad166609d65c8374dd2976157c1c51814a2b920e1a0e5968b97323"^^xsd:string ;
#     prov:endedAtTime "2019-04-09T00:00:08+00:00"^^xsd:dateTime ;
#     prov:generated scr:data_41896806fb0b_e6dd0a07 ;
#     prov:startedAtTime "2019-04-09T00:00:07+00:00"^^xsd:dateTime ;
#     prov:used scr:data_9880b63a8562_e1219b99 .
#
# scr:container_e6dd0a07-2964 a prov:softwareAgent ;
#     rdfs:label "Seismic Data"^^xsd:string ;
#     sc:containerInstanceId "e6dd0a07-2964-458b-8f9a-e132b7b17968"^^xsd:string ;
#     sc:imageHash "b393d5302daa8c17996fe15293d96fd1f99e7bae3f9353ad8bee8140bc764659"^^xsd:string ;
#     rdfs:comment "seismic data provided by ZAMG under http://geoweb.zamg.ac.at/static/event/lastday.json"^^xsd:string ;
#     prov:actedOnBehalfOf scr:operator_a06f54d52f45 .
#
# scr:data_03e046eb244f_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-08T00:00:01Z"^^xsd:string ;
#     sc:dataHash "03e046eb244f2f228f95e77d1bf75022e184dd755ff0305d22340e992c2668ee"^^xsd:string ;
#     prov:generatedAtTime "2019-04-08T00:00:01+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_03e8cef1559d_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-03T00:00:02Z"^^xsd:string ;
#     sc:dataHash "03e8cef1559d6a7f39ab3951884be444217be7c4e396225494d41c1fdb3880d2"^^xsd:string ;
#     prov:generatedAtTime "2019-04-03T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_06052e4f9c98_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-24T00:00:05Z"^^xsd:string ;
#     sc:dataHash "06052e4f9c98040b342dfd50045086f6d0c10151c282d23499e5c991ed5bee3b"^^xsd:string ;
#     prov:generatedAtTime "2019-04-24T00:00:05+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_1343e217b0fc_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-16T00:00:24Z"^^xsd:string ;
#     sc:dataHash "1343e217b0fc6794c3787924f49cea83b6c2cc3b47fb827ed2945057c144a4e0"^^xsd:string ;
#     prov:generatedAtTime "2019-04-16T00:00:24+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_16262fedeaf9_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-28T00:00:09Z"^^xsd:string ;
#     sc:dataHash "16262fedeaf92dcc2b9d7ef23fe91d3a1f2c45efb57e2c66381fd5f8fc9fd7e7"^^xsd:string ;
#     prov:generatedAtTime "2019-04-28T00:00:09+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_1a7c80cb5164_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-10T00:00:02Z"^^xsd:string ;
#     sc:dataHash "1a7c80cb51640678d76cf98f2f2cae7a72035090dd758bf27eaee225713b5199"^^xsd:string ;
#     prov:generatedAtTime "2019-04-10T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_1e1b22c9614d_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-05T00:00:01Z"^^xsd:string ;
#     sc:dataHash "1e1b22c9614da726e0c8a417c5a4691beb8db9eda2c110c9dad5dd30d5e5e80d"^^xsd:string ;
#     prov:generatedAtTime "2019-04-05T00:00:01+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_219ac0241153_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-30T00:00:14Z"^^xsd:string ;
#     sc:dataHash "219ac02411531a3aaee88fa76948a464f939fc12b8e6ec0ead3fa5a7bd45318c"^^xsd:string ;
#     prov:generatedAtTime "2019-04-30T00:00:14+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_26754122f832_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-03-30T00:00:02Z"^^xsd:string ;
#     sc:dataHash "26754122f8320b012045c4c0964bed03d654db747228c3d0d9353e5ea3e51e22"^^xsd:string ;
#     prov:generatedAtTime "2019-03-30T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_26c6e712b32c_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-27T00:00:03Z"^^xsd:string ;
#     sc:dataHash "26c6e712b32cf230868481d305c3b45ce25d89e51516a508e447546a78587544"^^xsd:string ;
#     prov:generatedAtTime "2019-04-27T00:00:03+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_2b2dfcb5ecd1_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-11T00:00:02Z"^^xsd:string ;
#     sc:dataHash "2b2dfcb5ecd1b28cb78e0718e34e065396ff6a9ebca3a06f5fc55cf0d6a22505"^^xsd:string ;
#     prov:generatedAtTime "2019-04-11T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_49dda3a5b415_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-03-31T00:00:02Z"^^xsd:string ;
#     sc:dataHash "49dda3a5b4159ccd91d87390efdb05a787d821fd0b831d4fdd3ba284b8a4e009"^^xsd:string ;
#     prov:generatedAtTime "2019-03-31T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_4e9c9a956594_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-07T00:00:02Z"^^xsd:string ;
#     sc:dataHash "4e9c9a956594812e3d1f29c699bda1d11476dbe8c29f52024c52d612260bc222"^^xsd:string ;
#     prov:generatedAtTime "2019-04-07T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_4f74eb37f31d_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-03-23T00:00:02Z"^^xsd:string ;
#     sc:dataHash "4f74eb37f31d8fbe3ff8ddcba9756daa06a76edf8abc121c892492043743155c"^^xsd:string ;
#     prov:generatedAtTime "2019-03-23T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_519d6ff9df57_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-26T00:00:04Z"^^xsd:string ;
#     sc:dataHash "519d6ff9df57ccde09b322dd1386f982713e8d54791ac2b3c40984c6a227bca5"^^xsd:string ;
#     prov:generatedAtTime "2019-04-26T00:00:04+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_622fb833fd5c_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-13T00:00:32Z"^^xsd:string ;
#     sc:dataHash "622fb833fd5cbc122a2542ff4c7d8746bcf13da2f35d0e552d01f1bc8a7094aa"^^xsd:string ;
#     prov:generatedAtTime "2019-04-13T00:00:32+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_62c1f359fa8b_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-03-21T21:48:13Z"^^xsd:string ;
#     sc:dataHash "62c1f359fa8b77a4950db7210307ad89c5f2fbbb839d854fe6a2b532c648d797"^^xsd:string ;
#     prov:generatedAtTime "2019-03-21T21:48:13+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_658bf7f78933_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-03-29T00:00:02Z"^^xsd:string ;
#     sc:dataHash "658bf7f78933e16835e7fd17a34f12dc83e90eb16707dc25035f769c2375c5df"^^xsd:string ;
#     prov:generatedAtTime "2019-03-29T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_7d2695093848_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-03-26T00:00:01Z"^^xsd:string ;
#     sc:dataHash "7d269509384829bfea1806f5c3ca137b68dbd52a40f6758835699b95f275d0d6"^^xsd:string ;
#     prov:generatedAtTime "2019-03-26T00:00:01+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_87c851f534de_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-14T00:00:05Z"^^xsd:string ;
#     sc:dataHash "87c851f534debee76dfbe5c5515c2aef4f5f166264667dc85d54bdf700c47afe"^^xsd:string ;
#     prov:generatedAtTime "2019-04-14T00:00:05+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_87f951443621_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-01T00:00:01Z"^^xsd:string ;
#     sc:dataHash "87f951443621c009d4375e1e025cb709942ae298bc0198208afc339a6992dab6"^^xsd:string ;
#     prov:generatedAtTime "2019-04-01T00:00:01+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_884c046c9736_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-03-24T00:00:02Z"^^xsd:string ;
#     sc:dataHash "884c046c9736ee697927ce4c30af1b28bdf9c01c93af72be5bcccf3c330c4c94"^^xsd:string ;
#     prov:generatedAtTime "2019-03-24T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_8b7408f76a55_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-21T00:00:03Z"^^xsd:string ;
#     sc:dataHash "8b7408f76a55de65098daad535e6a799db9479ed19d15b87005a6f201071df50"^^xsd:string ;
#     prov:generatedAtTime "2019-04-21T00:00:03+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_9878053b168f_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-12T00:00:02Z"^^xsd:string ;
#     sc:dataHash "9878053b168f3807f6887f18ef8bdac499a9c2d1c0909e4463aa34d119f97988"^^xsd:string ;
#     prov:generatedAtTime "2019-04-12T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_9880b63a8562_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-09T00:00:02Z"^^xsd:string ;
#     sc:dataHash "9880b63a8562cdaaf67943b72125760e47c1464411487d2fe7e187c2f7ed770e"^^xsd:string ;
#     prov:generatedAtTime "2019-04-09T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_98e849808579_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-03-27T00:00:02Z"^^xsd:string ;
#     sc:dataHash "98e849808579cee969f97514c385c329c1407bdc1a74fadeb5b4edcfd2f5d8a8"^^xsd:string ;
#     prov:generatedAtTime "2019-03-27T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_9b8d2b91aa3c_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-02T00:00:02Z"^^xsd:string ;
#     sc:dataHash "9b8d2b91aa3cd166fab783da509a3a9908ae598dbcacc0826af8f0018b5d911c"^^xsd:string ;
#     prov:generatedAtTime "2019-04-02T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_a419148e2936_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-20T00:00:02Z"^^xsd:string ;
#     sc:dataHash "a419148e29366036e32969521d2ab36146f7ec28f15ffba6b5dda79f9e6d3186"^^xsd:string ;
#     prov:generatedAtTime "2019-04-20T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_a565a05a41e5_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-17T00:00:19Z"^^xsd:string ;
#     sc:dataHash "a565a05a41e592115696d84e57607595d21500365dc93d50d853cb4a0c685a38"^^xsd:string ;
#     prov:generatedAtTime "2019-04-17T00:00:19+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_a6a58014d270_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-05-01T00:00:04Z"^^xsd:string ;
#     sc:dataHash "a6a58014d270ad1c23a99a15f337110f109a927c7c0b12144e04f4f113423c6e"^^xsd:string ;
#     prov:generatedAtTime "2019-05-01T00:00:04+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_a9cd50b1a8d3_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-18T00:00:07Z"^^xsd:string ;
#     sc:dataHash "a9cd50b1a8d3747f7cd2c9a0babe087bffa51f39b9811cad4655beb167bfe1da"^^xsd:string ;
#     prov:generatedAtTime "2019-04-18T00:00:07+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_b383e84cd3bf_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-05-02T00:00:09Z"^^xsd:string ;
#     sc:dataHash "b383e84cd3bfc523b922634ff8a390e6178501fd32ed0a1af19148f6402b85da"^^xsd:string ;
#     prov:generatedAtTime "2019-05-02T00:00:09+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_b4e6f971b245_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-04T00:00:01Z"^^xsd:string ;
#     sc:dataHash "b4e6f971b2455fc2fc75014120ac231161abf7aaf81d742b6b25aaf1b0fc7262"^^xsd:string ;
#     prov:generatedAtTime "2019-04-04T00:00:01+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_b86d56c18948_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-22T00:00:02Z"^^xsd:string ;
#     sc:dataHash "b86d56c18948e7e098b93accb962f0c3fcfba56bc0b899cea941290d6aa997fb"^^xsd:string ;
#     prov:generatedAtTime "2019-04-22T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_beea0b9c9401_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-03-28T00:00:02Z"^^xsd:string ;
#     sc:dataHash "beea0b9c940178f3ef6a33a38f8ebfc6bbf0636f0036e5492e6e13e919f29f72"^^xsd:string ;
#     prov:generatedAtTime "2019-03-28T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_bfa14dbae93c_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-19T00:00:05Z"^^xsd:string ;
#     sc:dataHash "bfa14dbae93c44b9d7f89118131732073eb7a3d2fdb3dd40d314df3678404658"^^xsd:string ;
#     prov:generatedAtTime "2019-04-19T00:00:05+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_d7a7b1da1156_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-25T00:00:02Z"^^xsd:string ;
#     sc:dataHash "d7a7b1da11560c9352ca6fe85744cd3f46946911baaf6013d463448221e2461c"^^xsd:string ;
#     prov:generatedAtTime "2019-04-25T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_dfc3c2cd4e32_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-15T00:00:15Z"^^xsd:string ;
#     sc:dataHash "dfc3c2cd4e3283aa6fdc73c6868e349aaf5d6aa86429f41be26062f6e2b37b85"^^xsd:string ;
#     prov:generatedAtTime "2019-04-15T00:00:15+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_e181e86cff83_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-29T00:00:04Z"^^xsd:string ;
#     sc:dataHash "e181e86cff838dc43c8a6ddb7674b885fb4bb24d7a92736fdc914276fb6bde33"^^xsd:string ;
#     prov:generatedAtTime "2019-04-29T00:00:04+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_e549c920185d_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-06T00:00:02Z"^^xsd:string ;
#     sc:dataHash "e549c920185dc1f8ea38288fc3e25f889596d20f315d4bdb6f2feec51407ae0a"^^xsd:string ;
#     prov:generatedAtTime "2019-04-06T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_f38589020f25_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-04-23T00:00:03Z"^^xsd:string ;
#     sc:dataHash "f38589020f256ecd8385ef96f19f2cbe7ee0502050f08c3686327d2b356af742"^^xsd:string ;
#     prov:generatedAtTime "2019-04-23T00:00:03+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:data_f8cd84c323dd_e1219b99 a prov:Entity ;
#     rdfs:label "data set from 2019-03-25T00:00:02Z"^^xsd:string ;
#     sc:dataHash "f8cd84c323dd1560e34d97e6632a634f500da6fbf33f23bf239f91c3ff31eaa7"^^xsd:string ;
#     prov:generatedAtTime "2019-03-25T00:00:02+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e1219b99-b99d .
#
# scr:operator_a06f54d52f45 a prov:Organization,
#         foaf:Organization ;
#     sc:operatorHash "a06f54d52f45af0234dcce50ca019c449e2c2ce7917dea27c1e11f92f5e1596d"^^xsd:string ;
#     foaf:mbox <mailto:dion@zamg.ac.at> ;
#     foaf:name "ZAMG" .
#
# scr:container_e1219b99-b99d a prov:softwareAgent ;
#     rdfs:label "Seismic Data"^^xsd:string ;
#     sc:containerInstanceId "e1219b99-b99d-48c2-96b3-eb1bc44d7639"^^xsd:string ;
#     sc:imageHash "2225b196116ad0a14acc952c6d56e6a717d9b37b0431b51dc94c979f5d2374c7"^^xsd:string ;
#     rdfs:comment "seismic data provided by ZAMG under http://geoweb.zamg.ac.at/static/event/lastday.json"^^xsd:string ;
#     prov:actedOnBehalfOf scr:operator_a06f54d52f45 .
#
# scr:data_41896806fb0b_e6dd0a07 a prov:Entity ;
#     rdfs:label "data set from 2019-05-02T13:04:17Z"^^xsd:string ;
#     sc:dataHash "41896806fb0b5ec4325cf10b74ae34e4c3f802758395364e88da140c403fb57f"^^xsd:string ;
#     prov:generatedAtTime "2019-05-02T13:04:17+00:00"^^xsd:dateTime ;
#     prov:wasAttributedTo scr:container_e6dd0a07-2964 .
#
# scr:source_0daa8a2813e5 a prov:Entity,
#         prov:PrimarySource ;
#     rdfs:label "Earthquakes in Austria and worldwide provided by ZAMG"^^xsd:string ;
#     sc:sourceHash "0daa8a2813e58d91e8776320ad90542466baa8a6e0da7025554d68866f9dc024"^^xsd:string ;
#     prov:hasLocation <http://geoweb.zamg.ac.at/static/event/lastday.json> .

# %% [markdown]
# The provenance document contains information on the data addition event as `prov:Activity`, the involved parties are modeled using `prov:Agent` or the subclasses (`prov:SoftawareAgent`, `prov:Organization`), and each data item that associated with each data modification activity as `prov:Entity`.
#
# For easier viewing, we can use [PROV-O Viz](http://provoviz.org) to generate visualization of this provenance information. We will use HTTP POST request containing the provenance information.

# %%
rv = requests.post("http://provoviz.org/service", data={'graph_uri':prov_url, 'data':g.serialize(format="turtle")})
rv
# Out:
# <Response [200]>

# %% [markdown]
# The response of this request contains HTML string, but in order to show it here we will use `IFrame` with data URL (otherwise the javascript won't work).

# %%
from IPython.display import IFrame
import base64
IFrame(src="data:text/html;base64,"+base64.b64encode(rv.text.encode("utf-8")).decode("ascii"), width="100%", height=400)
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
